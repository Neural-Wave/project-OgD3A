# %%
import pandas as pd

# Load datasets
low_scrap = pd.read_csv('/teamspace/studios/this_studio/dataset/low_scrap.csv')
high_scrap = pd.read_csv('/teamspace/studios/this_studio/dataset/high_scrap.csv')

# Basic data inspection
print("Low Scrap Dataset:")
print(low_scrap.head(), "\n")
print("High Scrap Dataset:")
print(high_scrap.head(), "\n")

# Check column structure
print("Columns in Low Scrap Dataset:")
print(low_scrap.columns, "\n")

print("Columns in High Scrap Dataset:")
print(high_scrap.columns, "\n")

# Confirm data types and missing values
print("Data Types and Missing Values in Low Scrap Dataset:")
print(low_scrap.info(), "\n")

print("Data Types and Missing Values in High Scrap Dataset:")
print(high_scrap.info(), "\n")

# Identify relevant target variable
target_variable = 'Station5_mp_85'
print(f"Target variable identified for causal analysis: {target_variable}")

# Save initial exploration results to guide further steps
# Out:
# Low Scrap Dataset:
#    Station1_mp_0  Station1_mp_1  Station1_mp_2  Station1_mp_3  Station1_mp_4  \
# 0       0.000164           10.0            2.0       0.000224           15.0
# 1       0.000240            8.0            2.0       0.000219           17.0
# 2       0.000160           11.0            3.0       0.000189           14.0
# 3       0.000173            9.0            3.0       0.000219           17.0
# 4       0.000212            9.0            2.0       0.000205           13.0
#
#    Station1_mp_5  Station2_mp_6  Station2_mp_7  Station2_mp_8  Station2_mp_9  \
# 0            3.0   37577.464524       0.003730       55728.48       38647.52
# 1            4.0   38731.386253       0.003738       56068.79       38993.59
# 2            4.0   39404.300798       0.003647       56295.66       39024.36
# 3            4.0   37393.410715       0.003700       54588.34       37205.51
# 4            4.0   39265.722068       0.003616       55140.14       37751.55
#
#    ...  Station5_mp_88  Station5_mp_89  Station5_mp_90  Station5_mp_91  \
# 0  ...    4.610773e+06        0.004900        11161.72        5580.859
# 1  ...    4.308434e+06        0.004918        11161.72        6042.939
# 2  ...    4.320958e+06        0.004795        10838.07        6490.280
# 3  ...    4.625802e+06        0.004947        11013.67        5999.359
# 4  ...    4.569075e+06        0.004930        11148.90        5907.712
#
#    Station5_mp_92  Station5_mp_93  Station5_mp_94  Station5_mp_95  \
# 0        0.005311        378.1243        0.000600     5482.792737
# 1        0.005281        393.5057        0.000627     5095.717933
# 2        0.005289        390.3012        0.000576     4195.970586
# 3        0.005361        389.0194        0.000551     4962.535809
# 4        0.005314        351.2070        0.000574     5205.339077
#
#    Station5_mp_96  Station5_mp_97
# 0    4.217334e+06        0.004869
# 1    4.039557e+06        0.004842
# 2    4.177828e+06        0.004766
# 3    4.194777e+06        0.004873
# 4    4.015814e+06        0.004855
#
# [5 rows x 98 columns]
#
# High Scrap Dataset:
#    Station1_mp_0  Station1_mp_1  Station1_mp_2  Station1_mp_3  Station1_mp_4  \
# 0       0.000190            7.0            2.0       0.000242           14.0
# 1       0.000182           10.0            2.0       0.000166           13.0
# 2       0.000152            6.0            2.0       0.000235           13.0
# 3       0.000185            8.0            3.0       0.000238           16.0
# 4       0.000169            8.0            2.0       0.000210           16.0
#
#    Station1_mp_5  Station2_mp_6  Station2_mp_7  Station2_mp_8  Station2_mp_9  \
# 0            5.0   40647.414812       0.003704       55426.62       38097.63
# 1            5.0   37508.035624       0.003632       55988.04       38620.59
# 2            4.0   35544.185038       0.003626       57232.01       40003.00
# 3            6.0   36826.252575       0.003663       56745.57       39628.07
# 4            5.0   41817.937611       0.003610       58600.95       41239.27
#
#    ...  Station5_mp_88  Station5_mp_89  Station5_mp_90  Station5_mp_91  \
# 0  ...    4.505663e+06        0.004916        11139.29        6312.113
# 1  ...    3.992388e+06        0.004541        11191.84        5899.380
# 2  ...    4.017937e+06        0.004914        11280.28        5529.588
# 3  ...    5.166438e+06        0.004945        11302.71        5493.698
# 4  ...    4.721392e+06        0.004715        11046.36        6004.486
#
#    Station5_mp_92  Station5_mp_93  Station5_mp_94  Station5_mp_95  \
# 0        0.005396        379.4061        0.000555     4844.358156
# 1        0.005342        396.0692        0.000551     5294.613653
# 2        0.005371        387.7377        0.000650     5933.540338
# 3        0.005391        371.0746        0.000580     5757.404641
# 4        0.005373        376.8426        0.000555     5126.268814
#
#    Station5_mp_96  Station5_mp_97
# 0    4.061648e+06        0.004840
# 1    4.058616e+06        0.004928
# 2    5.078599e+06        0.004887
# 3    5.003013e+06        0.004914
# 4    4.241679e+06        0.004914
#
# [5 rows x 98 columns]
#
# Columns in Low Scrap Dataset:
# Index(['Station1_mp_0', 'Station1_mp_1', 'Station1_mp_2', 'Station1_mp_3',
#        'Station1_mp_4', 'Station1_mp_5', 'Station2_mp_6', 'Station2_mp_7',
#        'Station2_mp_8', 'Station2_mp_9', 'Station2_mp_10', 'Station2_mp_11',
#        'Station2_mp_12', 'Station2_mp_13', 'Station2_mp_14', 'Station2_mp_15',
#        'Station2_mp_16', 'Station2_mp_17', 'Station2_mp_18', 'Station2_mp_19',
#        'Station2_mp_20', 'Station2_mp_21', 'Station2_mp_22', 'Station2_mp_23',
#        'Station2_mp_24', 'Station2_mp_25', 'Station2_mp_26', 'Station2_mp_27',
#        'Station2_mp_28', 'Station2_mp_29', 'Station2_mp_30', 'Station2_mp_31',
#        'Station2_mp_32', 'Station2_mp_33', 'Station2_mp_34', 'Station2_mp_35',
#        'Station2_mp_36', 'Station2_mp_37', 'Station2_mp_38', 'Station2_mp_39',
#        'Station3_mp_40', 'Station3_mp_41', 'Station3_mp_42', 'Station3_mp_43',
#        'Station3_mp_44', 'Station3_mp_45', 'Station3_mp_46', 'Station3_mp_47',
#        'Station3_mp_48', 'Station3_mp_49', 'Station3_mp_50', 'Station3_mp_51',
#        'Station3_mp_52', 'Station3_mp_53', 'Station3_mp_54', 'Station3_mp_55',
#        'Station4_mp_56', 'Station4_mp_57', 'Station4_mp_58', 'Station4_mp_59',
#        'Station4_mp_60', 'Station4_mp_61', 'Station4_mp_62', 'Station4_mp_63',
#        'Station4_mp_64', 'Station4_mp_65', 'Station4_mp_66', 'Station4_mp_67',
#        'Station4_mp_68', 'Station4_mp_69', 'Station4_mp_70', 'Station4_mp_71',
#        'Station4_mp_72', 'Station4_mp_73', 'Station4_mp_74', 'Station4_mp_75',
#        'Station4_mp_76', 'Station4_mp_77', 'Station4_mp_78', 'Station4_mp_79',
#        'Station4_mp_80', 'Station4_mp_81', 'Station5_mp_82', 'Station5_mp_83',
#        'Station5_mp_84', 'Station5_mp_85', 'Station5_mp_86', 'Station5_mp_87',
#        'Station5_mp_88', 'Station5_mp_89', 'Station5_mp_90', 'Station5_mp_91',
#        'Station5_mp_92', 'Station5_mp_93', 'Station5_mp_94', 'Station5_mp_95',
#        'Station5_mp_96', 'Station5_mp_97'],
#       dtype='object')
#
# Columns in High Scrap Dataset:
# Index(['Station1_mp_0', 'Station1_mp_1', 'Station1_mp_2', 'Station1_mp_3',
#        'Station1_mp_4', 'Station1_mp_5', 'Station2_mp_6', 'Station2_mp_7',
#        'Station2_mp_8', 'Station2_mp_9', 'Station2_mp_10', 'Station2_mp_11',
#        'Station2_mp_12', 'Station2_mp_13', 'Station2_mp_14', 'Station2_mp_15',
#        'Station2_mp_16', 'Station2_mp_17', 'Station2_mp_18', 'Station2_mp_19',
#        'Station2_mp_20', 'Station2_mp_21', 'Station2_mp_22', 'Station2_mp_23',
#        'Station2_mp_24', 'Station2_mp_25', 'Station2_mp_26', 'Station2_mp_27',
#        'Station2_mp_28', 'Station2_mp_29', 'Station2_mp_30', 'Station2_mp_31',
#        'Station2_mp_32', 'Station2_mp_33', 'Station2_mp_34', 'Station2_mp_35',
#        'Station2_mp_36', 'Station2_mp_37', 'Station2_mp_38', 'Station2_mp_39',
#        'Station3_mp_40', 'Station3_mp_41', 'Station3_mp_42', 'Station3_mp_43',
#        'Station3_mp_44', 'Station3_mp_45', 'Station3_mp_46', 'Station3_mp_47',
#        'Station3_mp_48', 'Station3_mp_49', 'Station3_mp_50', 'Station3_mp_51',
#        'Station3_mp_52', 'Station3_mp_53', 'Station3_mp_54', 'Station3_mp_55',
#        'Station4_mp_56', 'Station4_mp_57', 'Station4_mp_58', 'Station4_mp_59',
#        'Station4_mp_60', 'Station4_mp_61', 'Station4_mp_62', 'Station4_mp_63',
#        'Station4_mp_64', 'Station4_mp_65', 'Station4_mp_66', 'Station4_mp_67',
#        'Station4_mp_68', 'Station4_mp_69', 'Station4_mp_70', 'Station4_mp_71',
#        'Station4_mp_72', 'Station4_mp_73', 'Station4_mp_74', 'Station4_mp_75',
#        'Station4_mp_76', 'Station4_mp_77', 'Station4_mp_78', 'Station4_mp_79',
#        'Station4_mp_80', 'Station4_mp_81', 'Station5_mp_82', 'Station5_mp_83',
#        'Station5_mp_84', 'Station5_mp_85', 'Station5_mp_86', 'Station5_mp_87',
#        'Station5_mp_88', 'Station5_mp_89', 'Station5_mp_90', 'Station5_mp_91',
#        'Station5_mp_92', 'Station5_mp_93', 'Station5_mp_94', 'Station5_mp_95',
#        'Station5_mp_96', 'Station5_mp_97'],
#       dtype='object')
#
# Data Types and Missing Values in Low Scrap Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 98 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Station1_mp_0   2500 non-null   float64
#  1   Station1_mp_1   2500 non-null   float64
#  2   Station1_mp_2   2500 non-null   float64
#  3   Station1_mp_3   2500 non-null   float64
#  4   Station1_mp_4   2500 non-null   float64
#  5   Station1_mp_5   2500 non-null   float64
#  6   Station2_mp_6   2500 non-null   float64
#  7   Station2_mp_7   2500 non-null   float64
#  8   Station2_mp_8   2500 non-null   float64
#  9   Station2_mp_9   2500 non-null   float64
#  10  Station2_mp_10  2500 non-null   float64
#  11  Station2_mp_11  2500 non-null   float64
#  12  Station2_mp_12  2500 non-null   float64
#  13  Station2_mp_13  2500 non-null   float64
#  14  Station2_mp_14  2500 non-null   float64
#  55  Station3_mp_55  2500 non-null   float64
#  56  Station4_mp_56  2500 non-null   float64
#  57  Station4_mp_57  2500 non-null   float64
#  58  Station4_mp_58  2500 non-null   float64
#  59  Station4_mp_59  2500 non-null   float64
#  60  Station4_mp_60  2500 non-null   float64
#  61  Station4_mp_61  2500 non-null   float64
#  62  Station4_mp_62  2500 non-null   float64
#  63  Station4_mp_63  2500 non-null   float64
#  64  Station4_mp_64  2500 non-null   float64
#  65  Station4_mp_65  2500 non-null   float64
#  66  Station4_mp_66  2500 non-null   float64
#  67  Station4_mp_67  2500 non-null   float64
#  68  Station4_mp_68  2500 non-null   float64
#  69  Station4_mp_69  2500 non-null   float64
#  70  Station4_mp_70  2500 non-null   float64
#  71  Station4_mp_71  2500 non-null   float64
#  72  Station4_mp_72  2500 non-null   float64
#  73  Station4_mp_73  2500 non-null   float64
#  74  Station4_mp_74  2500 non-null   float64
#  75  Station4_mp_75  2500 non-null   float64
#  76  Station4_mp_76  2500 non-null   float64
#  77  Station4_mp_77  2500 non-null   float64
#  78  Station4_mp_78  2500 non-null   float64
#  79  Station4_mp_79  2500 non-null   float64
#  80  Station4_mp_80  2500 non-null   float64
#  81  Station4_mp_81  2500 non-null   float64
#  82  Station5_mp_82  2500 non-null   float64
#  83  Station5_mp_83  2500 non-null   float64
#  84  Station5_mp_84  2500 non-null   float64
#  85  Station5_mp_85  2500 non-null   float64
#  86  Station5_mp_86  2500 non-null   float64
#  87  Station5_mp_87  2500 non-null   float64
#  88  Station5_mp_88  2500 non-null   float64
#  89  Station5_mp_89  2500 non-null   float64
#  90  Station5_mp_90  2500 non-null   float64
#  91  Station5_mp_91  2500 non-null   float64
#  92  Station5_mp_92  2500 non-null   float64
#  93  Station5_mp_93  2500 non-null   float64
#  94  Station5_mp_94  2500 non-null   float64
#  95  Station5_mp_95  2500 non-null   float64
#  96  Station5_mp_96  2500 non-null   float64
#  97  Station5_mp_97  2500 non-null   float64
# dtypes: float64(98)
# memory usage: 1.9 MB
# None
#
# Target variable identified for causal analysis: Station5_mp_85

# %%
import numpy as np

# Combining datasets and selecting numerical columns
combined_data = pd.concat([low_scrap, high_scrap], ignore_index=True)
numerical_data = combined_data.select_dtypes(include=[np.number])

# %%
from castle.algorithms import PC  # Import PC algorithm from gCastle
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
from castle.algorithms import PC  # Import PC algorithm from gCastle
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np


# Scale the combined data
scaler = StandardScaler()
combined_data_scaled = pd.DataFrame(scaler.fit_transform(combined_data), columns=combined_data.columns)

# Initialize and fit the causal discovery model
pc_model = PC(alpha=0.01)
pc_model.learn(combined_data_scaled.values)  # Use the scaled values as input for gCastle

# Extract adjacency matrix from learned causal structure
adjacency_matrix = pc_model.causal_matrix

# Remove edges that violate the station ordering constraint
column_names = combined_data.columns  # List of column names in the data

# Get station numbers from column names
station_numbers = [int(name.split('_')[0].replace('Station', '')) for name in column_names]

# Modify the adjacency matrix to remove edges that go from a higher station number to a lower one
for i in range(len(station_numbers)):
    for j in range(len(station_numbers)):
        # If the source station is greater than the target station, remove the edge
        if station_numbers[i] > station_numbers[j]:
            adjacency_matrix[i, j] = 0


# Drop target if necessary
# Scale the combined data
scaler = StandardScaler()
combined_data_scaled = pd.DataFrame(scaler.fit_transform(combined_data), columns=combined_data.columns)

# Initialize and fit the causal discovery model
pc_model = PC(alpha= 0.005)
pc_model.learn(combined_data_scaled.values)  # Use the values as input for gCastle

# Extract adjacency matrix from learned causal structure
adjacency_matrix = pc_model.causal_matrix

# Convert adjacency matrix to graph for visualization
causal_graph = nx.from_numpy_array(adjacency_matrix, create_using=nx.DiGraph)

# Count the number of edges in the causal graph
num_edges = causal_graph.number_of_edges()
print("Number of edges in the causal graph:", num_edges)

# Visualize the causal graph
plt.figure(figsize=(12, 8))
nx.draw_networkx(
    causal_graph,
    with_labels=True,
    labels={i: column_names[i] for i in range(len(column_names))},
    node_size=700,
    node_color='lightblue',
    font_size=10,
    font_weight='bold'
)
plt.title("Causal Graph of Features Influencing Scrap Rates (High Scrap Data)")
plt.show()
# Out:
# Number of edges in the causal graph: 157

# %%
# Generate adjacency matrix
adjacency_matrix = pd.DataFrame(0, index=combined_data_scaled.columns, columns=combined_data_scaled.columns)
for edge in model.edges():
    adjacency_matrix.loc[edge[0], edge[1]] = 1

# Print adjacency matrix
print("Adjacency Matrix after applying directional constraints:")
adj_matrix_np = adjacency_matrix.to_numpy()



import numpy as np

# Replace 'matrix.txt' with the path to your text file
filename = '/teamspace/studios/this_studio/head15.txt'
# Load the matrix from the file
true_matrix = np.loadtxt(filename, dtype=int)

# count one in the true matrix
true_edges = np.count_nonzero(true_matrix)
print(true_edges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Generate adjacency matrix
#       2 adjacency_matrix = pd.DataFrame(0, index=combined_data_scaled.columns, columns=combined_data_scaled.columns)
# ----> 3 for edge in model.edges():
#       4     adjacency_matrix.loc[edge[0], edge[1]] = 1
#       6 # Print adjacency matrix
#
# NameError: name 'model' is not defined

# %%
import numpy as np

# Assuming `true_matrix` is loaded and already has 15 rows
# Assuming `adjacency_matrix` is the result from the PC model

# Ensure `adjacency_matrix` has at least as many rows as `true_matrix`
adjacency_matrix_subset = adjacency_matrix[:15, :true_matrix.shape[1]]

# Find indices where `true_matrix` has 1s (required edges)
required_edges = np.argwhere(true_matrix == 1)

# Count missing edges in the adjacency matrix
missing_edges_count = sum(1 for (i, j) in required_edges if adjacency_matrix_subset[i, j] == 0)

print(f"Number of required edges from true_matrix that are missing in the adjacency matrix: {missing_edges_count}")

# %%
help(PC.learn)
# Out:
# Help on function learn in module castle.algorithms.pc.pc:
#
# learn(self, data, columns=None, **kwargs)
#     Set up and run the PC algorithm.
#
#     Parameters
#     ----------
#     data: array or Tensor
#         Training data
#     columns : Index or array-like
#         Column labels to use for resulting tensor. Will default to
#         RangeIndex (0, 1, 2, ..., n) if no column labels are provided.
#     kwargs: [optional]
#         p_cores : int
#             number of CPU cores to be used
#         s : boolean
#             memory-efficient indicator
#         batch : int
#             number of edges per batch
#         if s is None or False, or without batch, batch=|J|.
#         |J| denote number of all pairs of adjacency vertices (X, Y) in G.

# %%
from castle.algorithms import PC
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Scale the combined data
scaler = StandardScaler()
combined_data_scaled = pd.DataFrame(scaler.fit_transform(combined_data), columns=combined_data.columns)

# Initialize and fit the causal discovery model with specified alpha
pc_model = PC(alpha=0.5)
pc_model.learn(combined_data_scaled.values)  # Use scaled values for gCastle

# Extract adjacency matrix from learned causal structure
adjacency_matrix = pc_model.causal_matrix

# Get column names to identify stations
column_names = combined_data.columns
station_numbers = [int(name.split('_')[0].replace('Station', '')) for name in column_names]

# Enforce directional constraints based on station order
for i in range(len(station_numbers)):
    for j in range(len(station_numbers)):
        if station_numbers[i] > station_numbers[j]:  # Remove edges from later to earlier stations
            adjacency_matrix[i, j] = 0

# Convert adjacency matrix to a DataFrame for easier indexing
adjacency_matrix_df = pd.DataFrame(adjacency_matrix, index=column_names, columns=column_names)

# Count the total number of edges found in the model's adjacency matrix
total_edges_found = np.count_nonzero(adjacency_matrix)
print("Total number of edges found in the model's adjacency matrix:", total_edges_found)

# Load the true matrix (first 15 rows and full columns) and count required edges
filename = '/teamspace/studios/this_studio/head15.txt'
true_matrix = np.loadtxt(filename, dtype=int)

# Ensure `adjacency_matrix` has the correct subset to compare with the true matrix
adjacency_matrix_subset = adjacency_matrix[:15, :true_matrix.shape[1]]

# Find indices where `true_matrix` has 1s (required edges)
required_edges = np.argwhere(true_matrix == 1)

# Count missing edges in the adjacency matrix
missing_edges_count = sum(1 for (i, j) in required_edges if adjacency_matrix_subset[i, j] == 0)
print(f"Number of required edges from true_matrix that are missing in the adjacency matrix: {missing_edges_count}")

# Visualize the modified causal graph
causal_graph = nx.from_numpy_array(adjacency_matrix, create_using=nx.DiGraph)
plt.figure(figsize=(12, 8))
nx.draw_networkx(
    causal_graph,
    with_labels=True,
    labels={i: column_names[i] for i in range(len(column_names))},
    node_size=700,
    node_color='lightblue',
    font_size=10,
    font_weight='bold'
)
plt.title("Causal Graph with Directional Constraints")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 14
#      12 # Initialize and fit the causal discovery model with specified alpha
#      13 pc_model = PC(alpha=0.5)
# ---> 14 pc_model.learn(combined_data_scaled.values)  # Use scaled values for gCastle
#      16 # Extract adjacency matrix from learned causal structure
#      17 adjacency_matrix = pc_model.causal_matrix
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/castle/algorithms/pc/pc.py:109, in PC.learn(self, data, columns, **kwargs)
#      87 """Set up and run the PC algorithm.
#      88
#      89 Parameters
#    (...)
#     104     |J| denote number of all pairs of adjacency vertices (X, Y) in G.
#     105 """
#     107 data = Tensor(data, columns=columns)
# --> 109 skeleton, sep_set = find_skeleton(data,
#     110                                   alpha=self.alpha,
#     111                                   ci_test=self.ci_test,
#     112                                   variant=self.variant,
#     113                                   priori_knowledge=self.priori_knowledge,
#     114                                   **kwargs)
#     116 self._causal_matrix = Tensor(
#     117     orient(skeleton, sep_set, self.priori_knowledge).astype(int),
#     118     index=data.columns,
#     119     columns=data.columns
#     120 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/castle/algorithms/pc/pc.py:397, in find_skeleton(data, alpha, ci_test, variant, priori_knowledge, base_skeleton, p_cores, s, batch)
#     395 for sub_z in combinations(z, d):
#     396     sub_z = list(sub_z)
# --> 397     _, _, p_value = ci_test(data, i, j, sub_z)
#     398     if p_value >= alpha:
#     399         skeleton[i, j] = skeleton[j, i] = 0
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/castle/common/independence_tests.py:91, in CITest.fisherz_test(data, x, y, z)
#      88 r = min(cut_at, max(-1 * cut_at, r))  # make r between -1 and 1
#      90 # Fisher’s z-transform
# ---> 91 res = math.sqrt(n - k - 3) * .5 * math.log1p((2 * r) / (1 - r))
#      92 p_value = 2 * (1 - stats.norm.cdf(abs(res)))
#      94 return None, None, p_value
#
# KeyboardInterrupt:
